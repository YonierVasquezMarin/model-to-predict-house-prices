# %% [markdown]
# # Práctica de varios conceptos de ML

# %% [markdown]
# ## 1. Histogramas con matplotlib

# %% [markdown]
# ### Definición
# Primero se genera la tabla usando pandas, luego usando matplotlib se genera un gráfico por cada columna de la tabla generada.

# %% [markdown]
# ### Código

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()
edades = [1,2,3,4,5]
df["edades"] = edades
df.hist(figsize=(5,3))
# Out:
# array([[<AxesSubplot: title={'center': 'edades'}>]], dtype=object)
